# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiragslnk/IDMB-CODSOFT/blob/main/imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
imdb = pd.read_csv('/content/sample_data/IMDb Movies India.csv', sep='|', encoding='latin-1')

# %% [markdown]
# Display top 10 rows of dataset

# %%
imdb.head(10)
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0   ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Raje...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
# 5  ...Aur Pyaar Ho Gaya,(1997),147 min,"Comedy, D...
# 6  ...Yahaan,(2005),142 min,"Drama, Romance, War"...
# 7  .in for Motion,(2008),59 min,Documentary,,,Ani...
# 8  ?: A Question Mark,(2012),82 min,"Horror, Myst...
# 9  @Andheri,(2014),116 min,"Action, Crime, Thrill...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# ...

# %% [markdown]
# check last 10 rows of dataset

# %%
imdb.tail(10)
# Out:
#       Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 15499  Zulm Ka Jawab,(1995),,Action,,,Surinder Kapoor...
# 15500  Zulm Ka Muqabla,(1993),,Action,,,Babu Antony,N...
# 15501  Zulm Ki Hukumat,(1992),,"Action, Crime, Drama"...
# 15502  Zulm Ki Pukar,(1979),,Action,,,Dinesh-Ramanesh...
# 15503  Zulm Ki Zanjeer,(1989),125 min,"Action, Crime,...
# 15504  Zulm Ko Jala Doonga,(1988),,Action,4.6,11,Mahe...
# 15505  Zulmi,(1999),129 min,"Action, Drama",4.5,655,K...
# 15506  Zulmi Raj,(2005),,Action,,,Kiran Thej,Sangeeta...
# 15507                 Zulmi Shikari,(1988),,Action,,,,,,
# 15508  Zulm-O-Sitam,(1998),130 min,"Action, Drama",6....
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# Find shape of our dataset(Number of rows and number of columns)

# %%
imdb.shape
# Out:
# (15509, 1)

# %%
print("Number of rows",imdb.shape[0])
print("Number of columns",imdb.shape[1])
# Out:
# Number of rows 15509
# Number of columns 1

# %% [markdown]
# Getting info about dataset like rows,columns,datatype

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 1 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  15509 non-null  object
# dtypes: object(1)
# memory usage: 121.3+ KB
